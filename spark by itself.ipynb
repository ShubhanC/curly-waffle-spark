# %%
import pandas as pd
import numpy as np

# %%
import pyspark
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("MyApp").getOrCreate()
# Out:
# 25/11/23 13:00:01 WARN Utils: Your hostname, Shubhans-MacBook-Pro.local resolves to a loopback address: 127.0.0.1; using 10.192.163.75 instead (on interface en0)
# 25/11/23 13:00:01 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/11/23 13:00:02 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/11/23 13:00:16 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %%
pandas_df = pd.read_csv('Loan_approval_data_2025.csv')
df = spark.createDataFrame(pandas_df)
df.show()
# Out:
# +-----------+---+-----------------+--------------+-------------+------------+--------------------+--------------+------------+----------------+-----------------------+----------------+--------------+------------------+-----------+-------------+--------------------+--------------------+-----------------------+-----------+
# |customer_id|age|occupation_status|years_employed|annual_income|credit_score|credit_history_years|savings_assets|current_debt|defaults_on_file|delinquencies_last_2yrs|derogatory_marks|  product_type|       loan_intent|loan_amount|interest_rate|debt_to_income_ratio|loan_to_income_ratio|payment_to_income_ratio|loan_status|
# +-----------+---+-----------------+--------------+-------------+------------+--------------------+--------------+------------+----------------+-----------------------+----------------+--------------+------------------+-----------+-------------+--------------------+--------------------+-----------------------+-----------+
# ...

# %%
df.printSchema()
# Out:
# root
#  |-- customer_id: string (nullable = true)
#  |-- age: long (nullable = true)
#  |-- occupation_status: string (nullable = true)
#  |-- years_employed: double (nullable = true)
#  |-- annual_income: long (nullable = true)
#  |-- credit_score: long (nullable = true)
#  |-- credit_history_years: double (nullable = true)
#  |-- savings_assets: long (nullable = true)
#  |-- current_debt: long (nullable = true)
#  |-- defaults_on_file: long (nullable = true)
#  |-- delinquencies_last_2yrs: long (nullable = true)
#  |-- derogatory_marks: long (nullable = true)
#  |-- product_type: string (nullable = true)
#  |-- loan_intent: string (nullable = true)
#  |-- loan_amount: long (nullable = true)
#  |-- interest_rate: double (nullable = true)
#  |-- debt_to_income_ratio: double (nullable = true)
#  |-- loan_to_income_ratio: double (nullable = true)
#  |-- payment_to_income_ratio: double (nullable = true)
#  |-- loan_status: long (nullable = true)
